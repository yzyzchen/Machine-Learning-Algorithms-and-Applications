# %% [markdown]
# # EECS 545 (WN 2024) Homework 4: Transformers
#
# <span class="instruction">Before starting the assignment, please fill in the following cell.</span>

# %%
###################################################################
# Enter your first and last name, e.g. "John Doe"                 #
# for example                                                     #
# __NAME__ = "Violet Fu"                                          #
# __UNIQID__ = "violetfy"                                         #
###################################################################
# ~~START DELETE~~
__NAME__ = "Violet Fu"
__UNIQID__ = "violetfy"
# ~~END DELETE~~
###################################################################
#                        END OF YOUR CODE                         #
###################################################################

print(f"Your name and email: {__NAME__} <{__UNIQID__}@umich.edu>")
assert __NAME__ and __UNIQID__
# Out:
# Your name and email: Violet Fu <violetfy@umich.edu>

# %% [markdown]
# # Transformer on text generation
# In this notebook, you will test the Attention Module and the PyTorch training code you implemented in **transformer.py** and **transformer_trainer.py**. This requires running code in PyTorch. Ideally, you should run this file on <span style="color: violet;">**GPU**</span>. If it is not available on your own machine, we recommand running on <span style="color: violet;">**Colab**</span>. Please refer to this [instruction](https://docs.google.com/document/d/e/2PACX-1vSgRhviaU_N_ErIwytT6vJ52gxmjiBcRGDs7q80qeifOVyuRkwZYchXMFn-HU0UjXrvmGzR2fB9QsOz/pub) about how to use Colab. If you evenatually decide to run everything with **CPU**, please start early and allocate at least a few hours for section(C) as it is going to take long.

# %% [markdown]
# ## Setup code
# Before getting started, we need to run some boilerplate code to set up our environment. You'll need to rerun this setup code each time you start the notebook. Let's start by checking whether we are using Python 3.11 or higher.

# %%
import sys
if sys.version_info[0] < 3:
    raise Exception("You must use Python 3")

if sys.version_info[1] < 11:
    print("Autograder will execute your code based on Python 3.11 environment. Please use Python 3.11 or higher to prevent any issues")
    print("You can create a conda environment with Python 3.11 like 'conda create --name eecs545 python=3.11'")
    raise Exception("Python 3 version is too low: {}".format(sys.version))
else:
    print("You are good to go")
# Out:
# You are good to go

# %% [markdown]
# First, run this cell load the [autoreload](https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html) extension. This allows us to edit `.py` source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Then, we run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
# Uncomment the lines below to install packages if they are not installed yet. 
# !pip install numpy==1.24.1 matplotlib==3.6.2 scikit-learn==1.2.0 imageio==2.25.1
import os
import sys
import json
import random

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Next, we need to make sure pytorch is installed. The following command will install pytorch if you haven't installed it before. Depending on your OS and GPU hardware, this may install a CPU or GPU version. If you want to use a GPU with PyTorch (which will exponentially speed up your computation time) you can follow the instructions on the pytorch [official website](https://pytorch.org/get-started/locally/). In this problem set a CPU-only pytorch is sufficient.

# %%
# uncomment and run the line below to install pytorch is you haven't done so
# !pip install torch==2.2.1 torchvision==0.17.1
import torch
from torch.utils.data import Dataset
from torch.utils.data.dataloader import DataLoader
# Out:
# Requirement already satisfied: torch==2.2.1 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: torchvision==0.17.1 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (0.17.1)
# Requirement already satisfied: filelock in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (4.10.0)
# Requirement already satisfied: sympy in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (1.12)
# Requirement already satisfied: networkx in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (3.2.1)
# Requirement already satisfied: jinja2 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (3.1.3)
# Requirement already satisfied: fsspec in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torch==2.2.1) (2.2.0)
# Requirement already satisfied: numpy in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torchvision==0.17.1) (1.24.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from torchvision==0.17.1) (10.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from jinja2->torch==2.2.1) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/violetfy/anaconda3/envs/eecs545/lib/python3.11/site-packages (from sympy->torch==2.2.1) (1.3.0)

# %%
# check if CUDA is available on torch
print('PyTorch CUDA is available?', torch.cuda.is_available())
# Out:
# PyTorch CUDA is available? True

# %% [markdown]
# To reproduce results, it is important to set seed. The function below helps to do so.

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    
set_seed(12345) #set a fixed random seed

# %% [markdown]
# ### Section(A) Check your attention implementation
# Now, let's check your transformer implementation. A correct implementation should pass the assert_allclose line and does not trigger any error.

# %%
from transformer import MaskedAttention
set_seed(12345)
attention = MaskedAttention(48, 3, 3)
inputs = [[[ 0.8852, -1.1841,  0.4406,  0.6939, -0.8548, -0.7011,  0.2941,
           0.6334,  1.6439,  0.2185, -1.8231,  0.3305, -3.6633, -0.5477,
          -1.5629,  1.3776, -2.3223,  1.1882, -1.0146,  0.4610, -0.6772,
           1.0473,  0.6797, -1.3599,  0.5765,  1.3818,  1.9596,  0.2333,
           0.4236,  1.5104,  0.5365, -1.2894,  1.0061,  0.0317,  0.9216,
           0.8358, -0.0778,  0.2040,  0.5083, -1.4204, -0.5308,  0.5121,
           1.4943,  1.3703,  0.4305,  1.2011, -1.8800, -0.1506],
         [-0.1161,  1.0082,  1.1272,  1.0432, -0.5849, -1.9456, -0.5046,
          -0.0495, -0.1723, -0.7835,  0.0706, -1.1203, -0.5606,  0.6311,
          -0.4215, -1.4242,  0.5186,  1.2899, -1.6057, -0.7066,  0.0234,
           0.0535, -0.1760,  2.7153, -0.3977,  0.4018,  1.7233, -0.4099,
           0.8925, -1.6363,  0.5603,  0.8228, -0.6935,  0.5939,  0.0261,
          -0.8228,  1.0020,  0.8776,  0.2597,  0.5770, -0.7814,  0.4137,
          -3.1109,  1.5095, -1.3054, -0.2762, -0.2339, -0.0605],
         [-0.9684,  0.8253,  1.1051, -0.7230,  0.3950, -0.3346, -0.0271,
          -1.6035, -0.3299,  0.6642, -0.4004, -0.6389, -0.2243,  0.8469,
          -1.0028, -0.2318,  1.4500,  0.1103,  1.2395,  0.2621,  1.8836,
          -0.6182,  2.1644,  1.5504,  3.0542,  0.9740, -2.8405,  0.8848,
           0.2762, -0.7397,  1.5389, -0.6161, -0.3589, -0.0085,  0.1275,
          -0.2849, -0.6918, -1.7355, -1.0572, -0.4486, -0.5446,  0.8705,
           0.8601, -0.1449,  1.4177, -0.2919,  0.7602,  0.4350]]]
inputs = torch.tensor(inputs).float()
attention.eval()
with torch.no_grad():
    outputs = attention(inputs)
expected_outputs = np.array([[[-0.1486,  0.1777, -0.3494, -0.2162, -0.1077,  0.0685, -1.0346,
                              -0.6672, -0.8616, -0.3380,  0.2046, -0.0050, -0.0738,  0.1913,
                               0.1332, -0.3641, -0.4243,  0.1188,  0.0215,  0.2370,  0.6812,
                              -0.1018,  0.0788, -0.6371, -0.4669,  0.6068,  0.1693,  0.1214,
                              -0.8412, -0.1185, -0.2494,  0.4053,  0.3242, -0.0280,  0.3158,
                              -0.2219,  0.1630, -0.0745, -0.1231, -0.6197,  0.5833, -0.3247,
                               0.3002, -0.1323, -0.4823, -0.5536, -0.1559,  0.5801],
                             [ 0.0702,  0.1089, -0.4341, -0.0671, -0.2151, -0.0183, -0.5890,
                              -0.6078, -0.8475, -0.4055, -0.1759, -0.0395, -0.0636,  0.2831,
                               0.0722, -0.1965, -0.2158,  0.1390, -0.2303,  0.2821,  0.5404,
                               0.0640,  0.1459, -0.4615, -0.3691,  0.2262,  0.1783, -0.0748,
                              -0.6773, -0.1486, -0.0890,  0.5385,  0.0556,  0.0576,  0.1533,
                              -0.0288,  0.0889, -0.0435, -0.1417, -0.2416,  0.4084, -0.2700,
                               0.0975, -0.1606, -0.4313, -0.4773, -0.0866,  0.2469],
                             [-0.1378, -0.1708, -0.2168, -0.0777, -0.0604,  0.0068, -0.6403,
                              -0.3968, -0.3044, -0.1192, -0.4150,  0.2027,  0.0118,  0.1063,
                              -0.1213,  0.2542,  0.0388, -0.0865, -0.2399, -0.0096,  0.3200,
                               0.0793,  0.0022, -0.1296, -0.0470,  0.1209,  0.0395,  0.3965,
                              -0.2515, -0.3861, -0.3169,  0.0824,  0.2049,  0.1243, -0.1657,
                               0.0492, -0.1103,  0.1369,  0.1256, -0.4973,  0.1020, -0.1457,
                               0.1124, -0.2355, -0.4387, -0.4518, -0.0035,  0.0864]]])

np.testing.assert_allclose(outputs.cpu().numpy(), expected_outputs, atol=1e-3)
print("Passed!")
# Out:
# Passed!

# %% [markdown]
# ### Section(B) Train your model to learn multiplication.
# The code base below is a math multiplication dataset for n-digit multiplication. Specifically, we are focusing on 2-digit multiplication problem in this homework, for example, for input 54x45, the expected output is 2430.

# %%
class DigitMultiplicationDataset(Dataset):
    def __init__(self, n, data_comb, split):
        self.n = n # max number of digit
        n_train = int(0.8*data_num)
        self.data = data_comb[:n_train] if split == 'train' else data_comb[n_train:]

    def get_block_size(self):
        return 4*self.n - 1

    def __len__(self):
        return self.data.nelement()

    def digit_to_str(self, x, ndigit):
        return f'%0{ndigit}d' % x

    def str_to_digit(self, x, device):
        factors = torch.tensor([[10**i for i in range(x.shape[-1])][::-1]]).to(device)
        return (x * factors).sum(dim=1)

    def __getitem__(self, idx):
        inputs = self.data[idx].item()
        a, b = inputs // (10**self.n), inputs % (10**self.n)
        c = a * b # target
        # encode digits
        astr = self.digit_to_str(a, self.n)
        bstr = self.digit_to_str(b, self.n)
        cstr = self.digit_to_str(c, 2*self.n) #2-digit numbers multiply to up to 4 digits.
        # we ignore * symbol because we only finetune on multiplication. 
        concat_str = f'{astr}{bstr}{cstr[::-1]}'
        concat = [int(s) for s in concat_str]
        x = torch.tensor(concat[:-1]).long() #given the sequence 01020
        y = torch.tensor(concat[1:]).long() #predict the next digit 10203
        y[:self.n*2-1] = -100 #masked out input
        return x, y

# generate data
ndigit=2
rng = torch.Generator()
rng.manual_seed(1337)
data_num = (10**ndigit)**2
data_comb = torch.randperm(data_num, generator=rng)

# %% [markdown]
# Run the code below to train a model that learns 2-digit number multiplication!
#
# If you are worried that the training break and you lose the training progress, you can refer to [PyTorch checkpoint](https://pytorch.org/tutorials/recipes/recipes/saving_and_loading_a_general_checkpoint.html) to save and load checkpoints while you train. Generally this will not happen for small models with short training time if you run on GPU.

# %%
from transformer import GPT
from transformer_trainer import Trainer, Evaluator

set_seed(12345)
train_dataset = DigitMultiplicationDataset(ndigit, data_comb, split='train')
test_dataset = DigitMultiplicationDataset(ndigit, data_comb, split='test')
n_layer, n_head, embedding_dim = 4, 4, 128
multip_model = GPT(n_layer, 
                   n_head,
                   embedding_dim, 
                   10, # 10 possible digits
                   train_dataset.get_block_size())

learning_rate = 1e-3
max_iters=20000 
multip_trainer = Trainer(multip_model, train_dataset, learning_rate, max_iters=max_iters)
multip_trainer.test_dataset = test_dataset
multip_trainer.run('multiplication')
# Out:
# running on cuda
# Iteration 1/20000: training loss 2.3560
# train accuracy: 1.93%
# Iteration 501/20000: training loss 1.2398
# train accuracy: 4.35%
# Iteration 1001/20000: training loss 0.9931
# train accuracy: 7.06%
# Iteration 1501/20000: training loss 1.0743
# train accuracy: 9.39%
# Iteration 2001/20000: training loss 0.9033
# train accuracy: 12.22%
# Iteration 2501/20000: training loss 0.8863
# train accuracy: 17.94%
# Iteration 3001/20000: training loss 0.7027
# train accuracy: 21.44%
# Iteration 3501/20000: training loss 0.6012
# train accuracy: 26.62%
# Iteration 4001/20000: training loss 0.6750
# train accuracy: 32.76%
# Iteration 4501/20000: training loss 0.5955
# train accuracy: 35.55%
# Iteration 5001/20000: training loss 0.6160
# train accuracy: 39.89%
# Iteration 5501/20000: training loss 0.4699
# train accuracy: 46.75%
# Iteration 6001/20000: training loss 0.4838
# train accuracy: 51.51%
# Iteration 6501/20000: training loss 0.3736
# train accuracy: 60.25%
# Iteration 7001/20000: training loss 0.2851
# train accuracy: 76.16%
# Iteration 7501/20000: training loss 0.2217
# train accuracy: 89.35%
# Iteration 8001/20000: training loss 0.2395
# train accuracy: 92.06%
# Iteration 8501/20000: training loss 0.1333
# train accuracy: 93.67%
# Iteration 9001/20000: training loss 0.1618
# train accuracy: 96.11%
# Iteration 9501/20000: training loss 0.1410
# train accuracy: 96.06%
# Iteration 10001/20000: training loss 0.1467
# train accuracy: 95.75%
# Iteration 10501/20000: training loss 0.0856
# train accuracy: 98.17%
# Iteration 11001/20000: training loss 0.0862
# train accuracy: 97.85%
# Iteration 11501/20000: training loss 0.0513
# train accuracy: 98.10%
# Iteration 12001/20000: training loss 0.0689
# train accuracy: 97.69%
# Iteration 12501/20000: training loss 0.1089
# train accuracy: 96.90%
# Iteration 13001/20000: training loss 0.0377
# train accuracy: 98.85%
# Iteration 13501/20000: training loss 0.0506
# train accuracy: 99.36%
# Iteration 14001/20000: training loss 0.0306
# train accuracy: 98.96%
# Iteration 14501/20000: training loss 0.0629
# train accuracy: 99.26%
# Iteration 15001/20000: training loss 0.0323
# train accuracy: 99.06%
# Iteration 15501/20000: training loss 0.0343
# train accuracy: 99.70%
# Iteration 16001/20000: training loss 0.0268
# train accuracy: 99.71%
# Iteration 16501/20000: training loss 0.0641
# train accuracy: 99.61%
# Iteration 17001/20000: training loss 0.0417
# train accuracy: 99.60%
# Iteration 17501/20000: training loss 0.0822
# train accuracy: 99.76%
# Iteration 18001/20000: training loss 0.0630
# train accuracy: 99.91%
# Iteration 18501/20000: training loss 0.0582
# train accuracy: 99.60%
# Iteration 19001/20000: training loss 0.0210
# train accuracy: 99.69%
# Iteration 19501/20000: training loss 0.0295
# train accuracy: 99.83%
# Iteration 20000/20000: training loss 0.0207
# train accuracy: 99.78%

# %% [markdown]
# Now let's evaluate the trained model on the held-out test dataset to see if it overfits. How does it perform? Please report the final training/testing accuracy.

# %%
set_seed(12345)
Evaluator(test_dataset, multip_model, 'test').eval_split(multip_trainer.device, print_example=20)
# Out:
# test accuracy: 93.55%
# Prediction: 26 x 61 = 1586, correct answer: 1586
# Prediction: 19 x 12 = 228, correct answer: 228
# Prediction: 31 x 92 = 2852, correct answer: 2852
# Prediction: 44 x 53 = 2332, correct answer: 2332
# Prediction: 89 x 8 = 712, correct answer: 712
# Prediction: 91 x 88 = 8008, correct answer: 8008
# Prediction: 6 x 59 = 354, correct answer: 354
# Prediction: 39 x 34 = 1326, correct answer: 1326
# Prediction: 94 x 35 = 3290, correct answer: 3290
# Prediction: 28 x 20 = 560, correct answer: 560
# Prediction: 54 x 98 = 5292, correct answer: 5292
# Prediction: 91 x 79 = 7189, correct answer: 7189
# Prediction: 79 x 52 = 4108, correct answer: 4108
# Prediction: 78 x 59 = 4602, correct answer: 4602
# Prediction: 35 x 8 = 280, correct answer: 280
# Prediction: 71 x 33 = 2343, correct answer: 2343
# Prediction: 1 x 10 = 10, correct answer: 10
# Prediction: 64 x 79 = 5056, correct answer: 5056
# Prediction: 5 x 8 = 40, correct answer: 40
# Prediction: 69 x 20 = 1380, correct answer: 1380

# %% [markdown]
# Now, let's plot the training loss.

# %%
plt.plot(multip_trainer.train_losses)
plt.xlabel(f'Iteration (every {multip_trainer.log_interval})')
plt.ylabel('Loss')
plt.title('Training loss history')
plt.savefig('multiplication_loss.png', dpi=256)
plt.show()
plt.close()

# %% [markdown]
# # Section(C) Train a model to tell stories!
# Now, let's train a model to tell short stories!
# We are going to train the model on the [tiny stories](https://huggingface.co/datasets/roneneldan/TinyStories/tree/main). Please open the link,
# download the **TinyStories-train.txt** file, and put it in your **data** folder like below.
# ```
# HW4 /
# --| transformer.ipynb
# --| data /
# ----| TinyStories-train.txt
# ----| ...
# ```
# Here is one example:
# *One day, a little girl wanted to paint. She went outside, and looked around. The grass was green, and the sky was blue. It was a mild day, so it was perfect for painting.
# The little girl began to paint, and she used all the colors from her box of paints. Red, yellow, and blue. She painted on the grass, and she made a beautiful picture.
# She painted flowers and birds, and she was very proud of her work. The sun was shining, so everything looked very bright.
# When she was finished, she stood up and looked at her painting. She felt very happy, because she had made something beautiful. She knew she would always remember this mild day and the painting she made on the grass.
# After this, run the code in the cell below to load the stories.*
#
# Now let's load the dataset you download and run the cell below to convert the loaded stories to a dataset class to use.

# %%
file_path = './data/TinyStories-train.txt'
unique_chars = set()
data_len = 0
with open(file_path, 'rb') as file:
    while True:
        chunk = file.read(int(1e7)) #we do this in chunk to make it compatible with limited memory
        chunk = chunk.decode('utf-8')
        data_len += len(chunk)
        print(data_len)
        if not chunk:
            break 
        for char in chunk:
            unique_chars.add(char)
sorted_unique_chars = sorted(unique_chars)
assert data_len == 1922767089
# Out:
# 9990541
# 19986053
# 29979590
# 39972496
# 49964221
# 59954744
# 69947926
# 79940655
# 89933160
# 99928581
# 109919710
# 119910748
# 129902928
# 139896391
# 149888178
# 159881199
# 169873894
# 179869931
# 189863959
# 199856631
# 209848705
# 219841890
# 229833658
# 239825767
# 249818837
# 259807060
# 269801357
# 279792976
# 289786644
# 299774936
# 309767611
# 319760703
# 329752566
# 339745445
# 349737886
# 359729917
# 369719428
# 379709871
# 389702304
# 399692943
# 409687812
# 419679435
# 429670934
# 439665761
# 449656535
# 459646571
# 469636971
# 479629305
# 489624570
# 499616200
# 509607173
# 519600427
# 529592271
# 539582706
# 549575280
# 559570986
# 569563255
# 579552136
# 589546001
# 599536655
# 609526751
# 619519615
# 629513148
# 639507741
# 649498613
# 659490898
# 669483078
# 679474017
# 689465989
# 699458313
# 709453334
# 719447801
# 729439368
# 739431062
# 749421700
# 759410541
# 769401244
# 779391457
# 789381979
# 799371128
# 809364056
# 819358481
# 829352799
# 839344304
# 849337143
# 859327322
# 869319666
# 879313146
# 889307503
# 899299915
# 909294765
# 919283521
# 929274636
# 939265275
# 949256402
# 959249497
# 969241652
# 979236771
# 989228170
# 999220263
# 1009212178
# 1019204370
# 1029195575
# 1039189202
# 1049183225
# 1059172896
# 1069167441
# 1079161599
# 1089153810
# 1099146369
# 1109135381
# 1119128703
# 1129118632
# 1139110356
# 1149104344
# 1159096108
# 1169089968
# 1179084927
# 1189075863
# 1199066150
# 1209060773
# 1219053020
# 1229047728
# 1239038394
# 1249031157
# 1259021800
# 1269015723
# 1279008653
# 1289001733
# 1298994127
# 1308984817
# 1318977419
# 1328971627
# 1338962816
# 1348955304
# 1358944787
# 1368938055
# 1378929344
# 1388917144
# 1398908572
# 1408902678
# 1418892205
# 1428885142
# 1438877617
# 1448869343
# 1458860528
# 1468851663
# 1478845419
# 1488836788
# 1498829930
# 1508821355
# 1518811974
# 1528802240
# 1538791152
# 1548784395
# 1558777009
# 1568766323
# 1578758409
# 1588748180
# 1598739916
# 1608732246
# 1618721087
# 1628712778
# 1638705051
# 1648695189
# 1658687382
# 1668681100
# 1678672895
# 1688663148
# 1698656438
# 1708645793
# 1718638100
# 1728628642
# 1738620594
# 1748612771
# 1758605562
# 1768597481
# 1778591322
# 1788584511
# 1798577789
# 1808568674
# 1818561092
# 1828555189
# 1838547275
# 1848542049
# 1858533826
# 1868527713
# 1878520066
# 1888509566
# 1898501647
# 1908495582
# 1918487342
# 1922767089
# 1922767089

# %%
class StoryDataset(Dataset):
    def __init__(self, file_path, chars, data_size, block_size):
        self.block_size = block_size
        self.loader = self.read_in_batches(file_path)
        self.data_size = data_size #1922767089
        vocab_size = len(chars)
        self.vocab_size = vocab_size
        self.stoi = {char:idx for idx,char in enumerate(chars)}
        self.itos = {idx:char for idx,char in enumerate(chars)}
        
    def get_block_size(self):
        return self.block_size
        
    def __len__(self):
        return self.data_size-self.block_size
        
    def __getitem__(self, idx):
        seq = next(self.loader)
        indices = [self.stoi[s] for s in seq]
        x = torch.tensor(indices[:-1]).long()
        y = torch.tensor(indices[1:]).long()
        return x, y
        
    def read_in_batches(self, file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            while True:
                batch = file.read(self.block_size)
                if not batch:
                    file.seek(0)
                    continue
                yield batch
                
block_size = 256
train_dataset = StoryDataset(file_path,
                             sorted_unique_chars, 
                             data_len,
                             block_size)

# %% [markdown]
# **Notice**: There is NO EXTRA CODE for you to implement in this section. You can directly reuse your code that you implemented in section(A) and (B). However, the model we are going to run is larger than the one from the section(B), therefore it is going to take <span style="color: violet;">**significantly longer**</span>, especially when running on CPU. Therefore, please start doing this **AS EARLY AS POSSIBLE**.
#
# Again, as training this model requires longer, it is possible that training breaks and you lose all the training progress, therefore if you are worried about this, you can refer to [PyTorch checkpoint](https://pytorch.org/tutorials/recipes/recipes/saving_and_loading_a_general_checkpoint.html) to save and load checkpoints while you train.
#
# In early iterations, the model will not generate anything meaningful, but as you train the model for more iterations, you will gradually see some interesting stories. The stories can be **imperfect** because we are only running a small model, but it should generate real words mostly, and follow grammar rules to some extent. Don't worry if the story is longer than the maximum length(1024 chars). Feel free to run it for longer (increase max_iters) or make the model size larger if you have time and want better results, but the default setting should be good enough.

# %%
from transformer import GPT
from transformer_trainer import Trainer, Evaluator

set_seed(12345)
torch.cuda.set_device(1) #you can ignore this line, it's to switch cuda device

n_layer, n_head, embedding_dim = 8, 8, 256
story_model = GPT(n_layer, 
                  n_head, 
                  embedding_dim, 
                  train_dataset.vocab_size, 
                  block_size)
learning_rate = 1e-3
max_iters=15000
story_trainer = Trainer(story_model, train_dataset, learning_rate, batch_size=64, max_iters=max_iters)
story_trainer.run('story')
# Out:
# running on cuda
# Iteration 1/15000: training loss 5.5238
# Story (1):
# Once upon a time.d e‒ d.‒    6 6 ‒′′.6‒	dCd e‒C	eee... 	.		  6 .6e ‒C.CC.C6   aii  6 6e .6e. C a .e莉. ′‒ de da′6CdC e 6 C	  e.′  	Ce  66 .分 e′  6e	     a ‒ee .a  6.  6.    a.edCC‒a6e.e   .′a6莉 .′  		′C e e d.e66e.ed CaC6e  ′′6 t    e   6C . 6′′a   e C i′′ee. e′6d6‒‒	a 6  ae6ed 6.′Ci. dC  aa′ aC ′ C‒6i dea a ′a 	‒ ′‒  	aa ′..a   e   i C    Ce′ e i  .  	   aCCa a  	a .′e‒ ‒C .    ‒.  a..d ‒6	′e6 a  6′  .      6a′Cda  e. .  iC  ‒ 6 . ‒.‒	aC.  ‒66.aC′aa  e‒‒  	.e i 6	6‒. 6′6a ‒e ‒a‒.′e .6i e . .6 	 a ′′aed‒e a 6  ′aCe‒ Ca′6e′  . C66i	.   ae	  e .分	′C a ′. ‒.′Ca C  C‒   		 .C′.a.. . ‒eee′a‒   6e ′. ′C.a     ‒ ′6.d      i aai.‒′′  6C  .	 ′ ‒‒. edee ′i .′6 ‒′	6e6 ′C 	  C ee6  	.a C C‒d‒ C‒   ‒	′e6  C a  a i.6eCee .a‒d‒′6 . ‒ C 	 ′d‒ a a.   e′..	 C ..	‒.Cee‒ ‒ 6  a6 ‒6′ eea ia′e′6a.ea.C..  . . a	 e′a.a 6.e  6 	  a   ′ae.′	  	6  ‒ 	  6iC‒  aa‒C 6′6 .6e6   a.′ee ′.		6 a.e 		C.′d  C  ‒d 	C 	‒ ee′	  	 eC6a6 6	  	ee ‒  eC6 C‒‒e ′ C‒  ed‒6 	a 6eaea. ′  ..ee′i  ii 	a	aa ae e‒ ′    .6 a ′. i′′C‒‒ ‒ 6 e  	 ea.‒  eeC aed 	 .	    C‒e ′   ′ 	e
# Story (2):
# Once there was an eC .C ‒66 a	d  ′C‒Ca′ a‒  d	 ′e e ′aeaidaC   a′ .i daa‒‒e‒ .e  	6Ce  6    6   i ‒ .莉  d .  C.e66  dC6eC	.a6′.′. ee 	C  ‒6 .′‒6eC.C‒i iC..	a6 Ci‒ e ′ e C ′‒a′a ad ′	.莉  ′a 	a   6  ..6e′ a 6.  6e‒aaC′.‒ 6  a莉. .eCd e‒a′6. a...6d′a  e     iaea′ ‒ee.edeea.	d6 . .    iee e   a6′C     6iC. a	e′.′.	. ‒e6e  e′i‒CeCCd′C ia	6. a.aae66‒	6.6e   ‒‒‒‒a a    ‒ C. aiC. 6iCa	CeaC ′ a	‒6‒ C.  Ci′a	C.e e ‒i‒e6ed′  aCie. a  Ced ed. 6 ′‒ aC′id′′C′ 6  e6 ee C. eCC  ′′iaaa id‒  ′a C ‒ .di  	6 ia  6e ′.eC e a .6i′	′e a‒	d ′i ′de′aC′.‒     ′C.  aed‒a.C 	′ede6 ee′′  Caed   a6   ed.aeCe a.   	6.‒e 6 6 6 6  6iC′ ..‒ aa6e‒e′e′d ′′.C6ee Ced e   6  e ‒′    ′6 aaC.‒‒	a 6 6ea  aCeC e  e ea a.eCe6.Ce a ..a‒a.′6C eC′	ed′.6 e ‒‒i a6 ‒ C a6i′C  ii6  6 ′  i C6C ae	e.6.eaC′. 	 e   e′ aa6i6.′C6  ieC′  ‒a‒ i6  .aii 	‒C′a6.aed C    i a6i .C′	6d 6 eCd    ‒Ca  a   . e ea    ′iae.   a ae  ′ a ‒ Ce ′dde6a.   6′i6ia	‒dCd   ′.aC6‒′   	ee6.′  aaii 6 ‒ edi‒′e6aC′eC‒. .e a ′ea C   ′ee‒    . 6..ae‒.eCC′.6e′e.a  6	e′ .6 e 	d′  e6Ci a6i ‒  ‒.ea′ .C C.	6C . e  ′
# Story (3):
# One day6a i ′ea  	 ide.e  6  i‒e a   e ′iee     ‒ .eeCa	e′′′6C 莉 eae′‒aea ‒‒e‒ deaa.e′Ca d   .C .	Caaeaae.  a . CeC′C‒′ ′ ed a′ a	d′‒ de  ′id a 6 e e d . ‒ a  dCad  6d ′	.‒6 . e′  6   a ‒ aaC C  	   .‒  a  ′′ de    i..C′′ a  ‒ed 	d‒..   eC 6e ′e C eaa‒6 ‒.  	a′′ .C  CC   ‒ ′	a e	′  ′a.‒6.C 	   ae‒  . ‒ii.	‒i.e‒ C.C e′ ‒ ai 	 e e  ′aC′   .a	ai 6C CC6e‒ a. a	e6 ..e  C′.6i6‒′ed 	‒′a′eee  .ae‒ ′i	 a e		ed′ 6i.   e	i6   aC ′a e66 C′ a 66e e′‒	da e‒ea′ ‒.a   6 Cai  ′	′aC.6.‒	d6e iC′	 ′′.  ′.  	d	′C6 e	  e	eae i e id	C 	.a  6  a 6 eC C iia ai‒ a  	66C . 	 dCe6a‒e  ′′  .e.	a  ‒  .aC6e‒e′i  i 	 e	6e   6′e e ae  d. ‒C‒Ca6 ‒ 6 C‒C  e ′  6	Ca′dC 	 e	 6ie e ′e 6.aa.  e. ae 66 iCi ee C6C  i.e .′ ..     C. i a	.a ae ee 6′6′.   aae	i a  e  iC 6‒′ aCe aCa .C′ C 6ie..eaea    aC   ′   C C‒a. 6e‒ C ..6′ .C.C   .‒′.  C . C 6e 	 .6 ae .a e e. ′a. C′.eCeeee′ eC′a ia‒6  C ieCi‒′C  . 6  a6′ 	a‒′e 	e CC6 	‒ e6Ca   e 6 e   .a 6 ′eae  a  6 .e. e.e    .′′ . a′′6	 C′6 C6 iee′e Cd e  C′ae′dea 6	6′6ia.eeCee   6..e  ‒ 6i′ 6  ′ ..′ ′	e e‒e.′ e	 	Ce
# Iteration 501/15000: training loss 1.7677
# Story (1):
# Once upon a time big a prepaning."
# The murt a andd "Lily. I wat a helllpat pay and and the to thy."
# Jook. They alll he mom. "I hap coull, id but the hoorke if you the fast fayo hast soot!" He harer. They took the to make his them. They make fid all. Tis doung had a fup. The houch amake her brick.
# Ake wan bitll and har tom teast. Som herered porkichen thit the welt. They heim they thint it holk here the chas heave houck alllll.
# She al tome the mat herimy. It hererere to to helllp.
# Sande sach swarke asid Timenterent and plot and splanell funends. They has breen and dof sthe pof fulplot. He wouthed she seskets. Thery mot cased tom. She why bout thived asme the bick shellirs and fud arende had them seee shim heroune togat fun seno the melinghth they. Shellpim dit imayst. Am foore a they tume.
# Litly amakes. I the lot and a her wad had was lome splind.
# They mim walllllkere herer the bup. Theire his shas thes henors aldandsid,. The flotsis and the thourt helery. Shelan thanky and soooune tomelk shey. And was pow the sthe follt ab
# Story (2):
# Once there was an plothoy bhaven a little of in whith fors. He thelpy a to play!" Timmy she happ allll and fuelt, Lily said, "I she fumm seeet. He milllert is sele hade you tay.
# Thimay, Lily heil said had dou, hery her forr had and sheren." The woy smum.
# <|endofttiext|>
# Then time samy, the cad was shelltcoug was her ham. She hery tome wullk and spit.
#
# Story (3):
# One day. I wo said fo or his por par. I to heir they soor it scan and. They was houny.
# <|edoftext|>
# One uponar on there a we hired thare to lay." She looked the was funt sther. She liked lots boy for she plance with this wased herers an. Les deay, big a splide then her phe foll sthimed thhere blome thellp fins then and herer foucil, Tomethe horer him, "Imo ande to ame bot but." I cknomed thime shellppoun theank who fom.
# The as sand tome fore her theich wish it the whery heank tho ame wastherer wheres on. Thentey was hererer help has and chere him.
# "Yanelllles wetas that tim they. Ye care bak foll the ande. And had herer put the sthowere bit in ound any, Jent alllloved and bem imintese the beammernt they wantherery.
#
# Iteration 1001/15000: training loss 1.2490
# Story (1):
# Once upon a time, there watched. One day, her had lated to be cat fast. She with so mom smiled the girl him. She was very helf. But the bessul and saw he dog to the was the ground. She asked that he car the came watch the packed the seame had a boath walk of her the had and he wind happy him was brothand to looke to pick of and wanted to be back. He felt so happy that she strick the chocletan down and side to hair hear the closer him. It listenings the watched bed it in was a spect car of her think it. She says, "That! I can and thank you for favor. I show you like you, I'mporther is found and card help mett a trun. Whave so a stay worl heartent the girl whited to the truck a places of the scudd and prettend her tewh trhings, he cried they carefully with a lonely atter. He went to see the garden, the walked to him. Sand the mont pot in the whould find becaught of it and the fanches in the cake. She could and said he lots too. He find that be didn't was hamppy an stuck the toystall. She said they sticked that to see they did
# Story (2):
# Once there was an playing with the water from happy. Then he losked and smiled friends.
#
# Story (3):
# One day, Ben was little going and had fun. She liked to plange with her boat. He was so happy. One day thought faming and felt back and brought him the dog. One day, She thried the more and the flooked hurt and hat to she friends away.
# He turna was did and the play with to was see and happpy of happy and playing to the down.
# The started that their mom and put with Mom that day day felt him. She did was so happy for of the hurrtche. She say Taraing, and The twent doner went and to see and small family. She started to give it and liked takes. He sees it a waiste turn it was for started to share to his bed. He feelt something in and shiled them was himsed the shappy. He thanked her for was away and shorpe the book fun.
# The says the picked outside and said the telle of something and playaged with friend, and letend the box felt it. One day, Tom said "Let's so bug so say?"
# They tails, potsrive the found of man. The diarter that the castache truck to he had. The was needbarere the swing to see spolisg with him and a headb
# Iteration 1501/15000: training loss 1.0266
# Story (1):
# Once upon a time there was a little girl named Lily. She felt hard worfing a flower in her flushy.
# But then, she found a show her to cook it up. She was they said the gracefully stopped a shiny and she would gave it up and was going to home, sure of her monster around in the wandon't take turns.
# When the sun move it became they came to high back to feest. The mosther build for make until he leaded owl bitter, the bear happened. She the sun shared the spead, galling careful hop and found something that she helped the floor. She said “Hello, I will be groke to a scare and time like, you disappointed it!"
# Joey, hoppped in the fancy together forgive the pretent and took a falward again. They did not late think so work.
# After the punnnysting replon that day on, it made her brave of the street. She went something speniblage work and said it would not do. She decishouted the melon and showed the bream in the house was so put three so creatured.
#
# Story (2):
# Once there was an amazing garden happy with him.
# One moral of the park of her friends with his maught. His mommy asked the bird why he was very and they couldn't work the person and enting. They tell be could said "Let's find me, you careful."
# The so smiled and put that the lesson and reade her spactory. She said her mom decided to bridge that day was time on her mom'sic so sharf. She was so excited her that day her custerfuins and dream and cheere was so excited and flash. She looked outside in the fox. She decided to go on and the butterfly worke, but she started to buy it, solve its hoppital coming white her new park!
# Back was worked to show there. She was so excited to shape the forest. She saw something her forke bricks. She was so cloud so surprised, “You try to fly on the park. It was time and boring, and it careful cup to help. She hugged it home and pushed staril. She stumbled bear last so excited too the cloth and thinkled with it her stun sirend and said get sure to check to see it. She reached out for dirt and chas
# Story (3):
# One day, Jack loved to show his the same a big house and went to the pond.
# The bird would stay to get away the sky, time was a smleet, that the butterfly didn't want all to play.
# The bird looked around and the boy was sad why a loud noise. He looked chars and find a chair and started to feeling door to find.
# The twoday waved up him was so excited. When it was a many broken, he found it and said, "You cont so high and comparted. You can here to place anymore. We can you think to do.
# The monston said, "Yi'm sort so happy. You can seend you," he said.
# Tim was so bought and went back in the flockippior and put the something stronge. Its satcked and decided to chick the peddle with her floor. His wanted to chear and talked at do his face.
# The little girl was too sise he had sure. Intill went outside and asked if she four a litttle litttle burneld. Finalling partents and her friends.
# The dad gentle and replied her family: that they loudd see wim one world all it. She felt saffe and true, it fest scafffialt to her deli
# Iteration 2001/15000: training loss 0.9781
# Story (1):
# Once upon a time, there was a little girl called Maxe in the warm. She was so surprised that she could get a storm of prince. She put the stone into her and smiled her papers, old the fun decider to go so many orange.
# Max's secret, tried to go out to the park, she cried. She smiled, as she was enjoying, she would follow the store he held her mom too. All on the morning, sounds the little girl and went inside the woods! The sun was gone in the room, she wanted to shoow it worked it. She have sunllashed of her around the water. She flew up and asked the whale had gone bettter.
# Then, she remembered the beach and don't worry.
# She was so huppy and she would bae the team. She was toing and that she was nice to eat something special playdle together and wanted, and soon the beach was not looking at her and look. She would paw inside and col back to the park sprinkle with herself. She had feeling so friends.
#
# Story (2):
# Once there was an elarn. It was so much fun. He loved to drive a happy so excited that someone a lot of fone.
# One day, Timmy's gust a big colorful hand again. Soon the pass tried he decided to read it. He hoppped his head.
# He threw so excited. The sun that she couldn't know. The fish made and helped him his friends were gone!
# Timmy thought no looked became on his show owner the candle, silly. Everywhenere every day, he went one to show his team.
#
# Story (3):
# One day, Lily wondered all the rock in the puddle old to go and a girl who would around her mom and dad.
# Lily started to rock the blue succh the toy. They were scared again, so the bird came back! But Lucy's friend store were to fine sort to more in the treess. She touched on the store. She picked up the till feeling so glea. She would across them the wind to make it big on aftern, so she had been gone.
#
# Iteration 2501/15000: training loss 0.9387
# Story (1):
# Once upon a time, there was a small named Timmy. Timmy loved to play in a sod. One day, she went on her room back a treasure where he arrived. She saw him and thought it was stuck at her home, and she would never learn a cruck. They had a toy that is a stoma big, and wait on me.
# Timmmy told his tears that it's not night. He chisteed once and when they had solve it. He is too happpy.
#
# Story (2):
# Once there was an ashame. Ben had lots of fun.
# One day, his mom had to see the forest. He wanted to be special! He said, "I can't fix it!" Lily said.
# Lily and Ben went to the store. They liked to play with him backs on the garden. She went on the boy and smelll. Lily felt excited to his bedry. She was so excited. She would never keeep his shoter, by anymor hard a family from the family paws time pink it happpy.
#
# Story (3):
# One day, Timmy's mom named Lily. It was shoulder that it was now. Lily came over to play the sand. It was very copsising and full of stars.
# Lily wanted to eat pastels, but it was in bread and penguil. She hugged her favorite them with them. Sam went to play outside, says, "Let's go to the stop. They ran to the store and share how many ignorinary her. We can't be paying on her toys anymore. Look, maybe it is not her bug and say he wants to share her. It is important. I am so proud and says, "Ouch, mom. Whe are not sorrry anyone. Come is too sccared on the door. Can you see a paint big that? We care it is a meaint hos shop."
# Ben and Ben sings to the fish. They are happuy and flashing as arothed. They see a botttle onfish. They are the radish and still fun to their park. They are their mom to get it and together. They see the spoon. They hears a twins and a toy car. And they allso reallize.
# After a while. They said that they heard mum a lot of fun. They arre happy. They hug enough and take a chirp of their hands and lo
# Iteration 3001/15000: training loss 0.8055
# Story (1):
# Once upon a time there was a family. They went to play with their mommy all day.
#
# Story (2):
# Once there was an interestly named Tim and Some loved to play games and holes. One day, Tim hears a loud noise. It has a room fun candy soll. It is bright and being friends. Tim and Sue is very brave and we love to play with the tug and have a big cat.
# Tim is a big human.
# Tim is happy and too. He trys to be misss. He likes his baby and he want to go to his toy to help another stories. He says sorry than to be finish, he sprays and beautiful human. He has time to go to the marble!.
# But Tim is funny. He likes that it is too bigg and she names a listter chair. He was scared and cross but sthe flower. He wishes he was hiding us. He looks small bird and his baby bag. Tim loves his mom and dad, and Sam are always as happy.
#
# Story (3):
# One day, Lily loved to play in her bag. It was a little girl named Ann. They had a lot of fun. See did not like it her hug. She wanted to say, banana. She hopped their dog again. She was always being careful. She said to Jack share her mom.
# Tom, Lily did not let help her feet anymore. She got a big share and talk about her dolls. She said, "This is always the fish near you. You have trust your dad at all days. You have to blank my red. You are a small best too big fish, so moved crayons. You can play with you, thank you."
# She said, "No, two, mom, this is in the grasss. You are not happy. It has a spicy. You made that be fine is yours song. You will not bridge if you share you can rescove your best cross. But I can con you come back to you."
# Tom was so excited. He talked about the forest and ran back to the sand and looked at the family. He licked Lilly and held his friend Tom for the crocoa. Tom and Jamie all are scared. They want to spend the leaves, and he realised he cut them that it is a nest, like the big best
# Iteration 3501/15000: training loss 0.8742
# Story (1):
# Once upon a time, there was a boy named Bane. He was happy when he was setting hot and the crab looks back inside. Every he would come closer with them and attach.
# One day, the crab got different and the little meadow around them. He would take a shrug them and show something else to them. He didn't have any moore strong, but nothing the wander came to the crab of the swing. It didn't know while he had held down.
# The crab held on the girl’s tree's stack and clapped! But the crab crabled it as he felt a great thing and set off home.
# He soon was very hopping to help. He was so glad he had something he wanted to pack to the crab laugh.
# He saw a toy. He couldn't reach up, but nobody the squirrel was very proud of himseving for him. He was so soft, he couldn't seem to take a warm walk. He looked around and pretted walking by as he could see it. His name was Trowing and all his new friend's happy boy. So, he went to his name when he saw somehing special. He swimming on the sea and asked his friend if he wanted to get better.
# The
# Story (2):
# Once there was an incross. He wandered and looked around and started to go outside in the sun.
# The bear was so scared. He stayed with the sky and counted out the prize for a delicious.
# The other princess asked him to the grape. Inside his family was still even tidy.
# The bear and the leopard were happy. The bear was so happy that he finished the sea to the world and stopped to together. They said, "Oh no. I can give you lots of teast freezer anymore anymore.”
# The bear looked around, blew and further the treasures wooker. She was coming from the door and seeing the woorld to spoil who wanted to be settter so helpful on her town heart.
# The bear tried the fooot felt so soft! She won the door was singing and felll asleep.
# When the foood woke up the leaves were going, the woood hugged the bear and hopped out for a bath helped. But it was too sleepy! It was a goood check and strong. The door cheered, and smiled. Finally, the dooor felt happy that the woood was going. He started to laugh of his friends and thought for for even btthi
# Story (3):
# One day, she was walking high. She went to her mom and dad was going too exited.
# At the end of the semediment, Mara asked her mom if she couldn't get wet. Mara continued the poor with her mom. She was getting holding out to the sea with her mom and she couldn't. She had so much fun that it was important to have a separation in her day. She had a strange day and wanted to help the car bucke with her mom and dad.
# As the cartooon, the stranger held the bird flew over, the child was the shile and the flamer had lots of fun. It couldn't wait.
# Alice had never seen what ever time. She lunch proudly wnere showing it to her mom, she wantded to explore it.
# She was so excited! Her mom came to the house bird and said, "Thank you! Do you for you feel happy bag. It's hot to do, but her mom says never forgive you to share you.”
#
# Iteration 4001/15000: training loss 0.8948
# Story (1):
# Once upon a time, there was a little bird named Pete. His name was Susie. She had a very special pond in her name and clapped up. Her family was always happy that she didn't want to get her.
# One morning, the pond flew down and said "Baters ift it is spoiled. And feel happy to be best friends," she said.
# Just then, her family said to her and they were the pond fasteauration. He had been shaked as she stepped up around.
# "Charm me, help me get on it!" asked John.
# The pond wondered was sad because he hadn't was his arm. Johnn and they held onto the flood and they played together. At first, they went out, enjoying the pond to get return, and they found a toy of the pond.
# Johnn smiled and said instead. He had a great on his head. He was so excited that he spread walking to the top of the broken.
# "Ha, own!" Mrs. Beauter said he gave the bag, hairy a little dolly car and a few minutes.
# Johnn and Johnn watched the friend's eye and told then they were very tired.
# Suddenly, they started to cry, a farrmer. Suddenly, a little girl na
# Story (2):
# Once there was an ard hope. He fouted a big tree with market in the air. He was so charming and shy that he was the street.
# One day, a squirrel hopped around, a bit mom was tired, and waved at a boat. She wanted to play onion.
# But when Jack was so careful, the boat was about to carefully the tree and putt the neck away. He was so excited!
# Suddenly, Pete heard a loud noise. He reached out for a long time! It was a small tree.
# "I named sure!"
# He replied Jack.
# He gathered a spider of sour that was late and smiled as he had a fierce. And he finallly looked for the tree to go closer. He smiled and said yes, and thanked the little bunny to help him.
# The little boy smiled. Then, he alll said and the rat. "The boy has the most soap!" he heard the little hot and said it was not stufffed. It was also little and shiny and the bottoy was scared, but he wanted to see what could do.
# Annd he thanked Jane and his friends threw back to get rich. He picked up the little bottle and said to aham. He smiled and said, "We, look!" Jane smiled. "Yo
# Story (3):
# One day, she went to the match and she had to see what it was. He was so excited, he ran home and started working. The man said in a great box and he saw a soft. The box had blinging in the box, enjoying it, some friends, but they had the box would be out of him.
# John's mom said that the soft son and should not safe him to see anything she wouldn't see it. Bow happpealled to a spider of the box and gonten to the door.
#
# Iteration 4501/15000: training loss 0.8551
# Story (1):
# Once upon a time, there was a little girl named Lucy. She loved to play outside the pages in the soft field. Her mom thought it was the best duck, so Lucy watched the toy field in the stable.
# She thought that the other pages had so much fun to try it on her lap'sh. It might be sick that the field was still all sort.
# Lucy asked, "What was wrong, Lucy?" asked the monkey from back home.
# Her mom said, "We're the bosss ok at the other pages that look all not best they have ever seen how blooming. Why are monkey is more cooler! Let's play it in it?"
# Lucy smiled and hugged it too. Luke that day. "Sorry, look why do not look so strong., Let's separate that wish mpretted me sharing is that that day."
# Lucy was not happy with joy. She threw it outside and the mouse started to move, but her mom strong told her her to go outside after her house.
# Lucy was so excited. She said, "Thank you, mouse! You are not here to go on way from my backpackppet with my house, but you have to share the bed of that my the trees is angry."
# The little g
# Story (2):
# Once there was an amonster who saw that the people was very borrowing and it was also the perfumes in the blanket was getting there to go for eil.
# One day, Benny sat down the same blanket and they decided to share the soft shirt with many things like it looked: but he didn't want to do this. Soon the staff saw that the perfume thought, so he couldn't give it back in too hough for his parent.
# Soon Randy thought about him.
# Sammy was so excited, and stared that the cat handed her hands. "Hu this! What is the trap is fun?s?" asked Lily and the deman noddded her headiest, him noddded.
# "I'm so happy and she didn't know what to do. We'll almost do to get and sorry for yours for the water. This day!" her mom came over. She said yes.
# Mom and Dad said, "I'm sorry, Mom. That's not too scared. We can't get important to do." Why did that the warte was the warth of her classroom, so the passha arrived forever. Doggy thanked his mom and told him that he was important to hold something exjurprised how the rains would be good for her.
# As the
# Story (3):
# One day, the little girl was called John. Jane was so scared to be cool. Her favorite thing way until the rabbit was cooler to the fire. Johnny was so excited to hear it.
# Theatil the rabbit got cooler from her, and the little boy returned to the hospital to a big, and Jane looked up at the street. She was amazed to take a special book, but June didn't want to spend the rabbit. So Jane and Jane spent a rabbbit next together outside! The strong was very scared and it started to rabbbit the rabbit.
# When Jane finished, they rabbited it every time. Sudddenly, the strong tasted the strong broke and Jane smiled.
# When the storm got to another car would bring the street, soo they bought it to him. Jane ran to the rabbit, the slide was able to tie them so much.
# Jane was no longer chanced and happy, but the strong made Leo get some wedding them into her room. She sprayed the street about the streats though it wasn’t tidyons. Finally, the three- smiling in them happy instead. From that day on, Leo and Jane completed them up all
# Iteration 5001/15000: training loss 0.8226
# Story (1):
# Once upon a time, but there was a big, candle water. This was a bang that loved the water creatures.
# One day, a big boy saw a big, wave that he wanted to clean up today. He saw a big boy called out of the water. All of the water said, "What are you doing in?" Stilll made the boy noddded.
# The boy said it was a soft big, and he said, "Thank you, through boy for a friend."
# The moral of the story is that it's okay to care of it is okay, and if you share it, we can try it outside?"
# The little boy ran overound and shared the boy with it with it another hands. He wished he had faced it and come into too fast!
# At the park, the more park was donllus! The park started to run to get the boy and was safe and warm. The dog could not set up to the boy. He felt so sad.
# The more was not scared to ryifal again. He screted up the boy and tried to make him feel better. He wanted to make his feelings so worried the little boy, but the more was soaring for something nicely.
# The boy felt both so rude he had let him listen to Jim and his mom playe
# Story (2):
# Once there was an umbrelllant. She loved to play with her friends.
# One day, the player woke up fell off the bushes in her players. Everything would always be happy to see how sparkled the melonado was able to see how much there were no only one. She loved it looking for it how to stay things and happpy and was so glad she had to feel more careful and colds. She said she was hlpping her safe again.
#
# Story (3):
# One day they heard then it was very curious and fun. The car was so pretty and he saw the same fog and thought it is wrong. He was afraid because he was all he was so too smart and he had fun. The mom said the test and took the balloon through a bite and it felt happy to have fun.
# The man looved his hands alll over to the walll around with him, and him around waiting for his help on his feelingg but. He forgot to play with his hoouse and do allways close to his balloon.
# The litttle girl shat the balllooon and made the lotion of hooot. She shuted the feel down and shouted away.
# "Help, help!" Tim said, holding out for a sislly sword ship for his discovery adventure had to make him fun.
# "Yes, wee can's sleeping water," Sara said.
# "Maybe we are discovering the monals is very cute than doing a few monster holding his wings are very fun.
# "I lay was a bad monster!" Sara shouted.
# Mia was very happy and calmed and cupiling. She wonded to help her mum find the monster to show him him how to give him a millk wheap. The monste
# Iteration 5501/15000: training loss 0.8157
# Story (1):
# Once upon a time, there was a little girl who was very small. She was a very careful, with picnic. She was okay.
# One day she saw a big send from one morning time. She waved it from the seat and asked her mom what it was. She waved in at the seat and said, “That is good.”
# The seat smiled and said, “That muse is just ok, Litttle Jane.”
# Little Jak smiled. “Tome alll of it won!”
# “When it was time to go here alll of her friends!” she said.
#
# Story (2):
# Once there was an elderly child. Jimmy loved to play books and he had lots of fun. He had found his bike and around and poured him back over. He was so excited that he giggled for his friends.
# Jimmy was so scared, he said, "What's that's the biggest child like?". His mom said, "I'm sick, Jump. The other is time for you." His mom carefullly put on him's side on the floor.
# She asked, "What are you doing too?" Jimmmy asked, "I'lll sing the phone is gone," he said, took there were an unusual skin.
# "Okay," shouted, her mom said. "That was a phone folllow it. I wull always find it."
# "But be careful, it's always time to go, but it's a distant suit" said her mom.
# "It's mine!" she ran outside to the carash, laughed.
# The little girl snifffed and cried.
# "I did it!" she said. "You can't find the special fat!"
# The girl went her mom and said, "That's a picture."
# "Oh, it's so cool. I don't understand what you did. And I don't want to do."
# The litttle girl said, “Let's pick it up.” So, they took a smalll piece of pieces.
# The girl smiled at
# Story (3):
# One day, he wanted to drive an apple. He drive around with the peppers filled the green, but he was now about what was in his hand. Everyone was happy to be resting for him and waving away!
# So the next day, Timmy asked his mommy what he was in his pocket own the ground, and his mommy asked him what happpened to him. Timmy was so surprised that he climbed out on the ground and cornered with him!
# Timmy was reallly happpy tired and he said, “You must never give it before. You must be sure it willl love matching who likes that!”
# Timmy and Jummy smiled and said “Won’t want to shout, Little bite, I am hurt your mom!”
# Mama smiled and said, “Ok, I told you nhow to be able to shout again.”
# Little Mama smiled. Also helped her dad comf to her mom and dad, “Okay,” she asked.
# But To onlyside her mom. “Ouch sure we should hug her daddy again, anything in the sky.”
# He said, “Yes. I can help this daddy, with ice cream and go home so she dancessed high and soon that if I could feed it again.”
# She clappped herg up the tigure and repl
# Iteration 6001/15000: training loss 0.8151
# Story (1):
# Once upon a time, there was a pretty blanket who lived in a fare. One day, a man went to the store to bed from the blanket. He was very embarrassed!
# "This is a red color. Don't you like to remove it twist up?" Ben asked.
# So, the blanket and showed them their teacerpt, "I know to take them to alll your dog. They are sorry. We are together. We will be strong, they can make your toys or make things will not break or allow their toys. They will be happy and shown her their mom some more."
# At their dog, their teacher agreed and wanted to be both happy. She toook them with him, but they always should have listened to Lila's mom.
#
# Story (2):
# Once there was an old lady. He had a family. He thought it was very dark and strength.
# One day, Timmy's mother told him that his special butterfly was holding a white butterfly flower with him. She hopped around the pond and saw a big cake. "Look at this! Let's go home. Me together. But this is not a trift. The cake makes a smalll trick. It is not a cake anymore. It is a flea with lost and snacks. Can I show you it? Come in?" She telled her what happened and said, "I do not want to warn you and important. I'm gloomye home. I need a mess. I do not want to show my tricks. Thank you, mom picked flowers. You need shoulds buy it with your friends. And thank you. You are a groceries. You are glad you are not safe. I love you tooo. They are not carried with jollies. And they are not happy. They take their toys and bottle. They pretend that their friends live."
# Mom says, "Sure, and we are very happy. We neeed it. We are just their toys. We love you, sweeetie. We love you tooo." She says, "But be careful, but you need this love."
# They
# Story (3):
# One day, they hopped over with Mom and Dad. They hopped around the trees and books. They hoped they would show Mom and Dad. They thanked Mom, and Dad. They both hoped they would make the water.
# Mom smiled. She hoped Tim was shared. She said, "Do you want to see me?" Mom said.
# They hoped they would not sleep in for anothers, but no one serva down. Suddenly, they heard Mom's mom coming to help. She said they could see alll their big beautiful blankets and houses.
# Tim remembered the best special man whenever he could teach something to hold. He went into a park. He saw them. He had an idea, but it was tooo talll to them.
# They decided to take their toys and choices to eat. They pretended they were better and clean their toys. They saw someone chocolate. They thought about it and the clown. They had many books. They were friends, and allways together.
# One day, they saw a boy playing with their toy cars and a tank walked to it. He wanted to see them and turn on the flooor.
# Then, they heard a loud noise that they both lo
# Iteration 6501/15000: training loss 0.7902
# Story (1):
# Once upon a time, there was a little girl named Lily. She had a big dreck and she loved to play with her toys. One day, Lily's mom told her to go to it. After they helped her find a big dreck. Lily's mom told her that her was not too late. Lily said, "They like it and please and trash top of the drecect druck. They are very prettty and shiny. They are not happy.
# When they worked hard and find some more, Lily helped her stir hard to winside. So, she got hurd, too late. She put it away. The spider wished she had done.
# The misssing moment continued to play. Lily thinked it. She turned to acppless and learned that it's important to be more borings and modest toys. She shared it with her friends and more mens when encourage toys was.
#
# Story (2):
# Once there was an old bird. She loved to watch!
# One day, Lily and her Mary decided to stay and play on an idea. They searched the table and cried. Lily and her mom said, "We should look for food together, but I want one friend."
# Lily replied, "I stay there, Mary. What are you doing?" Lily tool the cat gently said, "You are wearing foood and asking for you!"
# The family was happy and said, "Yes, you are a goood night. It's my dad's tupe, Lily and Ben. You did a match or a nice stick."
#
# Story (3):
# One day, Tim wanted to be dangerous. He found a big red pieces, a tree on the wall. Lily hopped in her hands, but she troked to find it. Her dad said, "Tim, you have to get closer. I'm going to be careful, but you have to paint."
# Tim was happy and thanked Tim for the tree. Lily felt brave and cozy and helped her get it. From that day on, the bird learned to be more careful with. Tim and his feeathers count the hotel with him each other and mum was not happpy.
#
# Iteration 7001/15000: training loss 0.6898
# Story (1):
# Once upon a time, there was a little girl named Lily. She was very proud of her farm boat who loved to watch her farm. One day, her brother Joe wanted to try and watch her farm song. She sang her arm and watched as the purrot felt like something that were finding it. When she got home, her brother said: "Don't worrry!"
# Joe gave the purrrot to alll his farm. Joe was happy with her mom and dad bought some time for hours. He had made a miserable nervous plate with a bad flower and watched it fit higher. The war wished he could reach it.
# The next day Joe decided to always try, when the flower suppply animaled away. She splashed alll day long, and every day she would watch it up and hide one day she would climb and hide behind it treees.
# One day Joe was walking down a cheeek three year old and she saw a litttle girl who wanted to go awlk through the park.
# Soo Juse asked her mum if she could have fun ake it, she said yes. She wanted to final her favorite musician, but she didn't know what it saw.
# Just then, the girl had an idea
# Story (2):
# Once there was an enormous spark. It was a plane with colourful flowers on the flower. They loved each other to fly around the flowers, and to save their silly flowers. They loved to swim in the park.
# One day, the spark was piled. He wanted to cover his her eather flowers with his wishy ship. He hoppped out the flowers and put his owner another powdal allight the powder in the snow. He went back to the flower and put the sun in the stair and his ships stilll flew up into stone. In the earth, the flowers were happy.
#
# Story (3):
# One day, as Lila suddenly came out of her shoe. She twirled to reach the blicks and ran after the day. She put on her shoes and ran back to him. It was dark and she couldn't see anyone. As she was reaching for some melons to go, she found an easer already frog and hoppped through the forest.
# She soon felt happy. She learned an imaginination who would help others all around her.
#
# Iteration 7501/15000: training loss 0.7763
# Story (1):
# Once upon a time, there was a boy named Tim. He was three years old and holding the shall bag.
# He ran to the box and looked at the floor. He saw a big cactus on the cactus. It was switch and full, and he hoped to start the floor. He forgot to start striking to spray his day. He asked Sunday, Sunday, and Messsing Sunday. Spike was scared.
# Sunday, Tom hiss dad said, "You have a gooat tomato with a new plate that is blue. You should have to share with you. You should have spray the day with your dollls. You should give them meat!"
# Tom and Mia were sorrry. They started to make the bird which was angry and scared. They duddy with the dollls, but the bird was very naughty.
# The doll was small and chefserful. They said, "It's okay, Lily. We have to have snow. We did not share their bird wstories at first. But they also did not want them. They wish they had to be nice and happpy." Lily was sad and angry and looved the dolll. She said, "This is is more not fun. Do not go anywhere. It will be the bird?"
# "It is an animal, Max. It is bad
# Story (2):
# Once there was an old cow. It was full of long white animals. It is shiny and silly, nosy and sister says to Ben, "Maybe you can share it. It is a big scough and thing. Do you want to play?"
# Ben nods and says: Later. It is sour and pretty. He says, "You are mighty, Lily. You are very clever. The do not mean things. You have sour. You have to play with it."
# Ben nods. He hopes that the fish is hiding but he is stilll seen budilts. He wants to make it fall again and to twinkle with it. He tries to throw it and tries to try. But the doctor will have toys. He was not afraid of them.
# "Ben, why did you say, Ben? I hope that they would like it!" he closes to Ben.
# Ben and the doctor want to play with an idea. They press Ben and make a name of the table. They pretend they were rocking boots of muds and feathers. They dance and swat at each other.
# Ben and Lily are hungry. They love their family. They love them alone. They make the tube feel better for their presents. They like to pretend they are blue and cozy and smart.
# "Maybe we can't
# Story (3):
# One day, Sally was sitting up and laughing. It had a pink bowl and a bike. Tom and Ben heard them. They saw something shiny.
# Ben smiled. He looked inside. He saw a man in his bed. He wanted to see what was inside. He saw the blouse and the shopkeeper. Sally sit in the sand at alll. Then, he heard an enterence from the house. They realized they were how calm Ben was almost anymore. They wanted to make them walk in the house with their paper.
# "Hello," Sallly said. "I don't like them. But I can hravel today. They were tooo small. We found them and wanted to catch them for instead."
# "Yes, it does!" Ben said, holding them and fixed their car some cheese, taking a loud balll, his face and stiping him and started to pick up. They smelled some water for their cars and looved ice. They flew high on, slippping and higher and high, and fall, but their favorite was taller and had long choes.
# "Mom,, what are you doing here?" Tom asked.
# Lily was sad because she was scared of the chooe and threw it in. It did not strike stopp. She
# Iteration 8001/15000: training loss 0.8180
# Story (1):
# Once upon a time, there was robot birdie named Jacky. Jacky was a very scared. The birdie wanted to take turns holding the stick.
# "Wow, that's scary, I'm careful," he said.
# Tom was scared, so he started to cry.
# After a while Jacky was driving out the sea, the wops made it from up into a litttling house. He cracked out of his hand and said, "I can't come back towards our house in the water."
# Lily toook a deep back and started to feed helping him to come inside and started to race back. She was very sad and wondered what was happpening up and waited for her to play.
# The giant was a goood friendly friend, a spider and started to reach the house. He was very scared and frustrated, he knew that the friendly mention was being safe.
#
# Story (2):
# Once there was an earth, name who his mom was very excited when he heard by the tight. He was very scared and scared. Tweetie said, "Twetie is not good, be thankful for the tight. It's very special to hear someone else."
# The little girl waved goodbye to the tight and loooked so thin exciting. She put the colourful message in the toy and started playing instead of it.
# Tweetie said, "Let's have done a great job! I can't go inside and have more fun!"
# The litttle girl smiled and said, "Of course I can have a trail the colorful messsage. I want to wish mome or didn't want you to catch it to get me in."
# Sam was not amazed at the appple. He thought that was a cozy moral of the story is that something would stop swimmming off! From that day on, Sam always began to worrry and clean a special mean cloud.
#
# Story (3):
# One day, a little girl called Amer and said, "Why, this arrow is the beautiful sunny thing on you, so I would take you home and I'll have to make you happy!"
# Amer smiled and looked at all the animals said, "It must steal my hair to go to the sky."
# The little girl liked that so she pushed something she would show her magic that watching the sun cake toogether.
# When she got there, the body said "Helllo! Who loying is confused?" he said.
# The little girl said gooodbye to the whale! Eventuallly noticed the sun stinging he could see many things observing.
# The boy waved gooodbye to the sun and waved it tasted its friend.
# The boy waved gooodbye and said thank you for being so cleaner. Every day a heart and could grab the task fy the boy while he found. The boy smiled and said, “That was so coool!”
# Everyone was happpy with the boy and thanked the boy again. The boy smiled and said, “I love you tooo, mom. I love to grab this boy.”
# The boy was so surprised, “What’s that?”
# His friend, a grabble. He was so grateful that he shou
# Iteration 8501/15000: training loss 0.7704
# Story (1):
# Once upon a time, there was a girl named Lily. She loved going on adventures. Lily wrote delicious clothes, cold treats. One day, a loud bush started to worry. It was a little boy. He picked it up and started to flap its skirt.
# But when Lily coming across a purple belll. He was stopping at Tim's colld coming, but he was flapping his arm hair. He started to slow down the streeet and he came facthing onto the treee. Suddenly, he saw a piggeon as the sun on the ground.
# When the colllection came inside, Tim saw a squirrrel on the streeet. It was a top of the temptation, but as he started speecial. As Tim was walking callos, he toook both of the squirrrel inside he was too tired to help. The squirrrell said, "It is time to go home home, Alleph!" sun back to the squirrrel and felt sad.
# The squirrrel started to protect his farm out of his curious dragon with its belt at the botttom. The next day, a litttle girl felt scared of the squirrrel and soon reached a farm to the ground. Her mom smiled and said they would held out and laughe
# Story (2):
# Once there was an old man who was seen a smooth dog. The dog was hopping to see the ball and laughing towards the paper and hugged him. He was very happy to learn new to bard.
# The dog could see the bald man with his shoes. He started to cry. But the bald man was tooo eager to help him. He wanted a spoot to steal to watch alll his shoes. He told her sobbood and the dog came acrosss a problem!
# The next day the dog was worrried and shouted, "Once that sounds!" But Julian was stubborn, just loooking. She had made a beautiful litttle parrade with stealing, breakfast on her big hipppoo and was scared. She ran outside and stooped to pick the litttle parrade. And she was playing in the sand when she was oceaning the daughter.
# But then, Amy shouted at her friend. Her friend asked Lily, to get it away from her hipppoo and said, “Let’s try picking the bellt!”
# Lily smiled and said, “Let’s walking!”
# Ben smiled and said, “Of course!”. So they toook the bellt to the third bellt and rottteen to the cake on the flooor. Whenever you wanted to
# Story (3):
# One day, Lucy wanted to sing and hop for a walk. She asked her mum if she looked up and saw how much she was wroing, it stopped and flew away. She felt so excited to see her mum pick it up.
# She smiled and went out for a long time. When she got there, the mum was neever tooo enoughy. "Light the mum is so bad aid to my son!" she said, pointing at the light. "Let's make a time," said her mum! "It loooks lightning!" her mum said, "No, that's what could it loooks she should do."
# The mum carefullly was time to get a discast trip with away, and they had to be careful when they came acrosss a charming wind. They were scared of shoes, but the wind was now she could not pommpany ever!
#
# Iteration 9001/15000: training loss 0.6468
# Story (1):
# Once upon a time, there was a boy named Timmy. Timmy loved to play outside in the big house with his friends, but it invited them to class them to check the big houses and see everything around.
# One day, Timmy's friend Timmy had an idea and they wanted to see her blocks. He ran to the kitchen and filled the house and grabbbed a tempt singing his house. Timmy had an idea and a lady worked hard toy from the birdrel and gave Timmy his napbles. Timmy and Lily said, "Thank you for saving me, Timmy. We love you, Timmy. Can you help me?" Timmy huggged Mia and said, "You have to play with me and play too?"
# Mia smiled and said, "Sure, you can't wear a little break. You are a good tedddy bear, but I love you too. But you are teoming more friends. Do you want to come with me?"
# Mia looked at Timmy and thought for a moment. She looked downstairs and saw a little reliable frog named Nesday. She wanted to pick more animals in the bathtub and had a famous package. She saw the frog and saw the fancy tedddy bear with a rhythm and a time until
# Story (2):
# Once there was an otter who had a big cord and a bike of treasure. He was very happy and started to cry. He was so excited when he realized he was going to be careful with his family what he did. He wanted to peer what was inside.
# "We are going to care from it and ran and jumped," he said. "Mom, it starts to feel gentle. Come on, let's carrry under the bench. Maybe it will funne."
# "OK, mom," Lily said. "But be gentle on you!"
# Her mom heard her and came over to them. "What does that?"
# "I don't know. She thought for a moment and saw a bird in it where you are looking different coffeees. She looked at the birds and beamed on the ground. She saw that her favorite toy was beneath and brother whings.
# Lily was sad and happy to hear the bird from her mom. She said, "Hi, Tom, you hope you like something to help me find your toys. You are making me healthy white and feed things. Thank you, Lily for such a gift from your bones and helps me find the toys. Let's make some animals wet on a lake."
# Tom smiled and said, "You are welcome, my sw
# Story (3):
# One day, they see a big dog and giggle in a chair. The dog likes to make turns swing and hang happy the snake to him. Then, they see a big cat with a big candle and a smelly snake.
# ...
# The treee said she did not told him to currie him on the treee to be at the stove. He was glad they curld help but try. He said it was bad about to always currry the those foood to make it hurt the treee. He said gooodbye to his mom and dad and they continued to watch her.
# <|endoftextext|>
#
# One day, Jilll went to the play with her mom and dad. They saw a big, hairy balll on the table and the window started to shive on the flooor. They were about to climb the laddder and the windows. They liked to cooun spie slowers and ran to seee the bush with a blue swing. They tooled it to the ship and the spie on the flooor.
# "Loook, Lily, you ar
# Iteration 12501/15000: training loss 0.5886
# Story (1):
# Once upon a time, there was a little girl named Lily. She loved to play outside and pictures. One day, she saw a little boy named Timmy. Timmy didn't want to spoil her.
# One day, while his turning, he saw a purple boy named Timmy. The boy was sad, but he didn't know what to do. Timmmy felt sad that wehen he tried, he didn't understand what. As he campped his turtle, he saw that he was feeling sad, but he wanted to share himself with him.
# "Because he comes to the park outside," said Timmmy. "Come inside to keeep pain, Mommmy! The paint is tooo high and busy."
# Just then, a little bird came into the rooom and said, "Oh no!" instead a loud loud noise again and agreed.
# Luckily, Timm found a whale in the rooom. He wanted to go inside with it, but he knew his toy always busy stairs something new. He tried to see it tooo. It tried to make it happpy.
# Luckily, the little bug got something and it wasn't loud anymore! It was a big turtle tear! The bug was very sad, but he wouldn't stop sighing anymore. The bug was gettting very strong a
# Story (2):
# Once there was an always shiny thing in the living room every day, so she would protect it and wrap her collection.
# One day, a shiny cabinet came across a book with a rabbit. The family was all very happy and they had a beautiful trophy. From then on, the cabinet knew the boook could both have as if he could sit he was gettting busy again. The family went to the cabinet anyway and trothed away. The end.
#
# Story (3):
# One day, she was feeling very sad. She went to the park to play, but she couldn't find her sweet boots. Then, an orange mountain came and said, "Baby, I'll be free you around my week you call into your family." The mountain was sad and tried to wipe to the family.
# The two friends tried to believe him to be very wellcome to him. They both had a lot of fun passtribes and worked together to mix care of it together. From then on, they had mixed together when they were going to hide from ear.
#
# Iteration 13001/15000: training loss 0.6977
# Story (1):
# Once upon a time, there was a little girl named Lily. She loved to watch them fly away. One of them saw something that made her fancy. It was difficult than big stars!
# One day, Lily said to her mommy, "I want, this is not nice to play with you. Can I play with it?" Her mom replied, "Of course, let's have shows!" Lily talended her for a while and played together. It was time for her to continue herself today."
# Lily was sad because she lost her fork. She thought it was amazing and so prettty. She said, "I won't wah you, Lily. It's important to share and have not to touch phinots."
# Later that day, the forkingott came runnning fast and said, "I won't wait. I can share it with you. I have some other phinots to take anything." So, Lily decided to touch a sillver sigator and asked, "How could you provide with chococolate and play? That's a new goood spider!"
# They hoped she was happpy to share the other phncilles and found a way to get to their sigators. They alll prank blocks and fougurt to protect each other and be carelesss.
# Lily
# Story (2):
# Once there was an elephant. The elephant was very friendly. He wanted to touch the castle. He wanted to play with the elephant. He didn't want to go on air anymore.
# He looked down at the elephant, but still still had to. He tried to touch his power further. He didn't want to play anymore because he was his momm angry. The elephant was broken. He decideded he couldn't sleeep anymore. He touched the stick studie and made a special face.
# But his friend asked him if he wanted to touch his piwer. His mom said yes, but the cop said no. The elephant started to climb. The tick didn't know his brown stat but trap its face. So, Timmmy ran to become incredible than anything.
#
# Story (3):
# One day, they saw a big building outside that saw the fire and crashing around.
# "Wow, the fire is a bit scary!" Ben said.
# "Tom, your fire is filled with some one else!" Lily said.
# They looked up and saw a pretty shiny small castle. The castle was bitter and crawled on the fire.
# But then, a big boy came and asked if the castle was fillling the rooad. The castle saw them and ran away. The castle asked what the castle said, "This is my castle. It is soft and shiny. I hope that my friend I cann seee them." The boy noddded and said, "Yes, time that my castle is soft and costooop!" So the castle agreeed and stoppped splashing the castle. Then the castle said, "No, this is my tie out of the strawberrra. It is mine now." Tom feltt sad.
# The scared and droppped the castle around the right forest. The castle broke falllen down and falllen. The tub broke out of its wagon. The day of the castle was scary, but he helped the castle in on the walll.
# The castle made loud and noisy and scroooked! It was so big and blumpy, amazed! The
# Iteration 13501/15000: training loss 0.6580
# Story (1):
# Once upon a time, there was a little girl named Lily. She loved to play on the swings and slide. One day, she saw a dirty dog hoping he would like to play with it.
# As Lily's dog was walking, she saw a big slide. She was hoping and through the store. She was scared and didn't know what to do. She tried her body falll, but it was far away. But Lily still didn't care. She wanted to lose her dolll.
# She said to Lily, "Daisy, come and continued to touch my big home. But the navy store makes the best modest things we don't know. They are not happpy. They stay calm and cold. Annna is afraid. She said no. She said they willl spend time on walking and drink my dlamas. She said no. She said they love each other and they said they loved each other. They said no. They however they saw the tasty balll back. So they had to go. The tasty balll. They had to go to the park.
# At last, they set un on. Tom picked up their balll. He swam around the tasty. He saw their tea lawyer on the gray balll. He felt scared.
# "Tom and Lily, a cool tea lawyer.
# Story (2):
# Once there was an incredible pieces. Thelling to their friend, Sam, who were walking by a big tree. Sam looked angry and climbed under the tree. He looked up and saw their pieces of their hole. He looked around but he couldn't find the bunny. It had a big red cake. Sam and Sam searched and searched on the black tree for each other.
# Later that night they had seen. They both felt cold because they tried to take an one. They felt happy, but they did not see the bin playing. They did not move anywhere. They said to each other, "Sara and Mama, why are we scared, mom? We must not deaf."
# "I don't neee the poli!" Mom!
# Mom said, "Oh no, you have to argue more. You are not scared or scareing. You have to say the policeman. You can have the balll. How do you want to pay your misster together?" Mom asked.
# Them smiled. He liked cheeese. He pain and taught her how much fun. He had a balll. He wanted to go to the store. He hopked the ceiling was able to put her balll. He hoppped on the coub. He loooked up and saw a big tree callled on the do
# Story (3):
# One day, Lily went for a walk in the park. She found a shovel and a big red stick.
# "Mom, I have a stick. I don't think the bear is good. I want to drop it. It bites your scarf." Lily said, holding her big car.
# "It's okay, Lily. I want a cookie to make it crazy. It hurts my scarf. Dear you count to scarf and find a rabbit?" Ben shouted.
# Lily and Max were scared. They ran away and angry and cried. They bit the brush and the table. They did not like the rabbit. They were not ashamed. They were gentle. They did not like the bird.
# "Sure, I do not like the log most bleed rainining anymore. We have to be careful. We are cold. We can buy the table. And we can be friends. Come with us. Let us be careful." the bird chirped. He ran back and from the light.
# Lila was scared and ran down the lady. She shouted her mom and huggged Lila. She was so scared. She grabbbed her mom and showed her how heavy he then hoppped until they had an idea. They wrote her aboad and held her a big hug and a hat.
# Sudddenly, Lila heard a voice. "What i
# Iteration 14001/15000: training loss 0.5903
# Story (1):
# Once upon a time, there was a little boy named Timmy. Timmy loved to play outside and explore the world around him. One day, he saw a big, scary beook in the middle of the beautiful scary cactus. Suddenly, he heard a loud noise and fell into the mud pad. Timmmy screamed and ran after his toy beeef, but he couldn't find it.
# He spottted a shiny beot of chalk and it was tooo loud. "Hi, chalk! That was my favorite cactus. Do you want to play with it?" Lily said.
# "No, I want it. I should be careful with it," Timmmy said tricked to help his friends.
# They realized that they should always put the cactus back together," Timmmy replied. "Mix, cactus!" , Lily said. "But only for setture?"
# "Okay, they don't have money," Timmmy replied.
# "Okay, I willl be careful. But then, we willl come with you.
# A bike?" Lily asked.
# Tommmy tool peened into the cactush and how happpy he said yes, but this time, she started to telll stories about fairiding things.
# "Sure remember, bike, we can put the bike in other songs!" the bike said.
# "OK, we can play
# Story (2):
# Once there was an old car named Timmy. He was very happy, but he was also strong and the old car was that he could help him.
# One day, Timmy saw a secret. Benny wanted to know what was inside. "Ow, ow, ow, ow, ow. And ow, ow, ow!" Lily grinned and said. "Come in, come opinions, my darllinary children!" Timmmy didn't want to know what to say. He pickedked a bite of what he could."
# "What happpens he said, moom, therere my castle is yummy!" Lily shouted.
# Mom put the hat out, "It's almost bad! But be careful, Timmmy," Timmmy replied.
# As the man walked, Timmmy noticed something shiny. He tried to have buried it away, and Lily's castle was weak and she couldn't fix it. She ran outside and ran over to the bathrooom every day.
# When she got tired, Timmmy's eyes went outside and said, "Lily, come on, let's get it." His mom said, "Wow, thatt's wonderful. Don't be weak, we'lll get a wipe on a swing, okay?" Lily didmn't understand what him did bewetly. She wanted to get on swing, but she asked him if he could guesss it would be help keeep h
# Story (3):
# One day, Jimmy and his friends decided to play with their cars. But Jimmy felt sad for himself for taking a break. He leaned a hard leash and was sad. From that day on, Jimmy and his friends played with the other kids playing along the ball every day.
#
# Iteration 14501/15000: training loss 0.7035
# Story (1):
# Once upon a time, there was a little bird named Tim. Tim loved to play with his toys. One day, he went to a park with his friend, a princess, a friendly dog named Max. Tim wanted to play with Max instead of his team.
# "Hi, I am Lily. What is your name?" Tim asked excited.
# "I don't know, Tim," Tim said. "Maybe we can show it to Max. Max is tooo hard for the stars."
# Lily folllowed Max to him. She put a doll on the ground. When he picked up a storm with luggage, it was a litttle scared. Max tried him. He helped Max move away and hugged his steak.
# He told Max he was tooo heg for Max to help he put the stars in an empty fort. Max pretended to be pirate. He was blue and hard for his steak and happpy too she could find his work. He was happpy.
# Max gave him a blue star with his star. Max liked to sing. He toook a nice star from his show. He promised to never be lesss fair because hey were not.
#
# Story (2):
# Once there was an inegirl named Max. Max loved to eat his tar. One day, Max got a cat named Tom. He was scared of his tail. He did not want to be celebrathed. Max felt very brave. He showed Sam and his tail.
# Max thought to himself, "I will wait for you. He made you a mask. He loves you very much. He was very much. He wanted to marrry you again. He said that he was brave and kind and kind. He willl be more proud and complete. He hoped to hop, but friends listened to Sara and the squirrrel.
# Sara and Tom started to play with each other. They wanted to be happpy. They played with the big egg until it was time for the guys and hiding something to hope. They asked the squirrrel, for the guys, bad eggs, and the coins, for his toys and cooin. The squirrrel said he would go to Lily and the squirrrel. Lily pretered a bunny and tucked a band-aid on it. The squirrrel was so fulll of sausams which we had to have enough money for a huge more.
# The sun was very hard that Tom could go and get their sausam from Lily and Tim. Lily huggged the s
# Story (3):
# One day, he found a big pile of cake. "This big dog is burned," Lily said.
# Tom thought it was a good idea. "I think that big menu can make it look nice. It is just like a star. Do you want to clean it?" Sam asked.
# The man tipped over the tree, shook his head and checked his head.
# "No, thank you! That's not a fairy. You made a messs!" Lily said. She grabbbed the pinch and shouted.
# "It's okay, dog. You can try. It's not a messs. It's a dog. You can try it tooo. Hay for you. But you have to print it first. Hay fair. It is our messs. You have to learn about your shape. And you have to win." she said.
# Ben did not listen. He was sitting on the ground and trying to give up.
# At loook, Ben decided to win serious for the shape to buy something that he warned. He said he was telling his friend that the lady was fine to play with. Ben said he was playing with his shape and things and having fun. He said he would not wait to swim away for it again. He smiled and said he wanted to play with any toys.
# Ben started to cry. He dared
# Iteration 15000/15000: training loss 0.6193
# Story (1):
# Once upon a time, there was a girl named Lilly. She loved to help her mom whistle a small tower. One day, Lilly's mom asked her to play with her toys to practice on fun.
# Lilly felt happy that she wanted to catch her tower and tear her screws. She put an old wool in it tonight, and she smiled at her mom's face. She said, "Loook, Lilly, a tower!" Her mom smiled and said, "Thank you, Lillly. You're my surprise."
# After a few weeeks, Lilly's face came true. "Let's come hereal the tower again," her mom said, "we have no weel!". Lillly was happpy when she could study the tower. And she could not get her surprmise to drive much tower.
#
# Story (2):
# Once there was an old man named Tom. Tom lived in a small corner on a center on a forest. One day, Tom's mom gave him a space. Tom asked, "What are you doing, my lovely?" Tom said, "I don't know, Tom." Tom was very sad and strange at Tom's head. They wanted to hear the man's friends. Tom wipt the man in the boring forest. He ran inside the house and ran inside. They smiled and said, "Let's fix this morning?"
# Tom noddded, eager to catch Tom's bike. He did not hear the loud noise. He smiled with delight when he tried to fix it, but he could never fix things again. He waved gooodbye to the leopator and went fast again through and waved back home.
# Tom was happpy to have his bike so he crosssed his feeet in the water. He felt happpy and freee again.
#
# Story (3):
# One day, Anna's mom told her to help and get it sad, but she wanted to make a wonderful storm. But Anna didn't want to make her sad orange. She said, "No mice, shooting many people were very sick."
# Anna said, "I want to help people, Anna. I will help you clean. You are not more fire to use me to make her happpy."
